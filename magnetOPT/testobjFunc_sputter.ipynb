# %%
import objFunc_sputter

# %%
test = objFunc_sputter.Erosion(30, 125)
hist = test.erosion_profile()
print(hist)
# Out:
# running:   0%|                                                            | 0.00/100 [00:00<?, ?B/s]c:\Users\URCS_simulation team\Downloads\Xsec (2)\mlStepcoverOPT\topolopyOPT_sputter\magnetOPT\sputterSimulator.py:241: RuntimeWarning: invalid value encountered in arccos
#   theta0 = np.arccos(v[:, 2]/vMag)
# c:\Users\URCS_simulation team\Downloads\Xsec (2)\mlStepcoverOPT\topolopyOPT_sputter\magnetOPT\sputterSimulator.py:88: RuntimeWarning: invalid value encountered in cast
#   i = np.floor((pos_cp[:, 0] - start_x) / dx).astype(int)
# c:\Users\URCS_simulation team\Downloads\Xsec (2)\mlStepcoverOPT\topolopyOPT_sputter\magnetOPT\sputterSimulator.py:90: RuntimeWarning: invalid value encountered in cast
#   k = np.floor(pos_cp[:, 2] / dx).astype(int)
# running: 100%|██████████████████████████████████████████████████████| 100/100 [32:19<00:00, 19.4s/B]
# [  34   90  170  234  288  355  401  513  533  630  688  792  825  884
#  1012 1044 1096 1167 1202 1293 1350 1411 1533 1611 1696 1748 1731 1840
#  1792 1943 2013 2107 2024 2101 2250 2264 2268 2356 2415 2508 2656 2533
#  2687 2731 2889 2852 2941 3104 3104 3169 3312 3500 3342 3612 3704 3699
#  3717 3725 3826 3875 3893 4013 4113 4179 4227 4296 4386 4356 4542 4429
#  4486 4497 4476 4706 4642 4873 4881 4888 5048 5045 5181 5196 5398 5406
#  5581 5557 5504 5671 5724 5890 6195 6099 6178 6147 6264 6366 6319 6515
#  6388 4915]

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, axs = plt.subplots()

# We can set the number of bins with the *bins* keyword argument.
bins = 100

dist = axs.plot(hist)
axs.set_title('Erosion')
axs.set_xlabel('r[mm]')
# Out:
# Text(0.5, 0, 'r[mm]')
